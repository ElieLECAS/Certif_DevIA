# %%
from vanna.ollama import Ollama
from vanna.chromadb import ChromaDB_VectorStore
import os
from dotenv import load_dotenv
load_dotenv()

class MyVanna(ChromaDB_VectorStore, Ollama):
    def __init__(self, config=None):
        ChromaDB_VectorStore.__init__(self, config=config)
        Ollama.__init__(self, config=config)

# Configuration pour Ollama basé sur le service Docker
# Le service ollama est exposé sur le port 11434
vn = MyVanna(config={
    'model': 'llama3.2:1b',  # ou un autre modèle installé dans Ollama
    'ollama_host': 'http://localhost:11434'  # URL du service Ollama
})

vn.connect_to_postgres(
    host=os.getenv('POSTGRES_HOST'), 
    dbname=os.getenv('POSTGRES_DB'), 
    user=os.getenv('POSTGRES_USER'), 
    password=os.getenv('POSTGRES_PASSWORD'), 
    port=os.getenv('POSTGRES_PORT')
)

# %%
# # Récupérer les métadonnées du schéma
df_information_schema = vn.run_sql("SELECT * FROM INFORMATION_SCHEMA.COLUMNS")

df_information_schema # Afficher la réponse brute
# Out:
#      table_catalog        table_schema            table_name  \
# 0             GMAO          pg_catalog               pg_type
# 1             GMAO          pg_catalog              pg_class
# 2             GMAO  information_schema                tables
# 3             GMAO              public              demandes
# 4             GMAO          pg_catalog           pg_stat_ssl
# ...            ...                 ...                   ...
# 2137          GMAO  information_schema  routine_column_usage
# 2138          GMAO          pg_catalog   pg_stat_replication
# 2139          GMAO          pg_catalog       pg_subscription
# 2140          GMAO          pg_catalog      pg_statistic_ext
# 2141          GMAO  information_schema        udt_privileges
#
#            column_name  ordinal_position column_default is_nullable data_type  \
# 0         typsubscript                13           None          NO   regproc
# 1       relpersistence                16           None          NO    "char"
# 2         table_schema                 2           None         YES      name
# 3         commentaires                10           None         YES      text
# 4            client_dn                 6           None         YES      text
# ...                ...               ...            ...         ...       ...
# 2137  specific_catalog                 1           None         YES      name
# 2138  application_name                 4           None         YES      text
# 2139        subskiplsn                 3           None          NO    pg_lsn
# 2140      stxnamespace                 4           None          NO       oid
# 2141       udt_catalog                 3           None         YES      name
#
#       character_maximum_length  character_octet_length  ...  is_identity  \
# 0                          NaN                     NaN  ...           NO
# 1                          NaN                     NaN  ...           NO
# 2                          NaN                     NaN  ...           NO
# 3                          NaN            1.073742e+09  ...           NO
# 4                          NaN            1.073742e+09  ...           NO
# ...                        ...                     ...  ...          ...
# 2137                       NaN                     NaN  ...           NO
# 2138                       NaN            1.073742e+09  ...           NO
# 2139                       NaN                     NaN  ...           NO
# 2140                       NaN                     NaN  ...           NO
# 2141                       NaN                     NaN  ...           NO
#
#       identity_generation  identity_start  identity_increment  \
# 0                    None            None                None
# 1                    None            None                None
# 2                    None            None                None
# 3                    None            None                None
# 4                    None            None                None
# ...                   ...             ...                 ...
# 2137                 None            None                None
# 2138                 None            None                None
# 2139                 None            None                None
# 2140                 None            None                None
# 2141                 None            None                None
#
#      identity_maximum identity_minimum identity_cycle is_generated  \
# 0                None             None             NO        NEVER
# 1                None             None             NO        NEVER
# 2                None             None             NO        NEVER
# 3                None             None             NO        NEVER
# 4                None             None             NO        NEVER
# ...               ...              ...            ...          ...
# 2137             None             None             NO        NEVER
# 2138             None             None             NO        NEVER
# 2139             None             None             NO        NEVER
# 2140             None             None             NO        NEVER
# 2141             None             None             NO        NEVER
#
#      generation_expression is_updatable
# 0                     None          YES
# 1                     None          YES
# 2                     None           NO
# 3                     None          YES
# 4                     None           NO
# ...                    ...          ...
# 2137                  None           NO
# 2138                  None           NO
# 2139                  None          YES
# 2140                  None          YES
# 2141                  None           NO
#
# [2142 rows x 44 columns]

# %%
# # Générer le plan d'entraînement
plan = vn.get_training_plan_generic(df_information_schema)
print(plan)

# Entraîner le modèle
vn.train(plan=plan)
# Out:
# Train on Information Schema: GMAO.pg_catalog pg_type
# Train on Information Schema: GMAO.pg_catalog pg_class
# Train on Information Schema: GMAO.pg_catalog pg_stat_ssl
# Train on Information Schema: GMAO.pg_catalog pg_index
# Train on Information Schema: GMAO.pg_catalog pg_attribute
# Train on Information Schema: GMAO.pg_catalog pg_stat_progress_cluster
# Train on Information Schema: GMAO.pg_catalog pg_shseclabel
# Train on Information Schema: GMAO.pg_catalog pg_indexes
# Train on Information Schema: GMAO.pg_catalog pg_database
# Train on Information Schema: GMAO.pg_catalog pg_amproc
# Train on Information Schema: GMAO.pg_catalog pg_stat_progress_vacuum
# Train on Information Schema: GMAO.pg_catalog pg_stat_database
# Train on Information Schema: GMAO.pg_catalog pg_default_acl
# Train on Information Schema: GMAO.pg_catalog pg_stat_user_tables
# Train on Information Schema: GMAO.pg_catalog pg_largeobject
# Train on Information Schema: GMAO.pg_catalog pg_statio_sys_tables
# Train on Information Schema: GMAO.pg_catalog pg_shadow
# Train on Information Schema: GMAO.pg_catalog pg_locks
# Train on Information Schema: GMAO.pg_catalog pg_available_extensions
# Train on Information Schema: GMAO.pg_catalog pg_stat_bgwriter
# Train on Information Schema: GMAO.pg_catalog pg_collation
# Train on Information Schema: GMAO.pg_catalog pg_ts_config
# Train on Information Schema: GMAO.pg_catalog pg_stat_all_tables
# Train on Information Schema: GMAO.pg_catalog pg_stat_sys_tables
# Train on Information Schema: GMAO.pg_catalog pg_cast
# Train on Information Schema: GMAO.pg_catalog pg_enum
# Train on Information Schema: GMAO.pg_catalog pg_stat_xact_user_functions
# Train on Information Schema: GMAO.pg_catalog pg_stat_sys_indexes
# Train on Information Schema: GMAO.pg_catalog pg_stat_activity
# Train on Information Schema: GMAO.pg_catalog pg_stat_replication
# Train on Information Schema: GMAO.pg_catalog pg_rewrite
# Train on Information Schema: GMAO.pg_catalog pg_depend
# Train on Information Schema: GMAO.pg_catalog pg_available_extension_versions
# Train on Information Schema: GMAO.pg_catalog pg_tables
# Train on Information Schema: GMAO.pg_catalog pg_sequence
# Train on Information Schema: GMAO.pg_catalog pg_stat_wal
# Train on Information Schema: GMAO.pg_catalog pg_largeobject_metadata
# Train on Information Schema: GMAO.pg_catalog pg_hba_file_rules
# Train on Information Schema: GMAO.pg_catalog pg_stat_progress_basebackup
# Train on Information Schema: GMAO.pg_catalog pg_stat_wal_receiver
# Train on Information Schema: GMAO.pg_catalog pg_statio_user_indexes
# Train on Information Schema: GMAO.pg_catalog pg_statio_user_tables
# Train on Information Schema: GMAO.pg_catalog pg_policy
# Train on Information Schema: GMAO.pg_catalog pg_publication_tables
# Train on Information Schema: GMAO.pg_catalog pg_sequences
# Train on Information Schema: GMAO.pg_catalog pg_stats_ext
# Train on Information Schema: GMAO.pg_catalog pg_stat_all_indexes
# Train on Information Schema: GMAO.pg_catalog pg_foreign_server
# Train on Information Schema: GMAO.pg_catalog pg_trigger
# Train on Information Schema: GMAO.pg_catalog pg_file_settings
# Train on Information Schema: GMAO.pg_catalog pg_stat_xact_sys_tables
# Train on Information Schema: GMAO.pg_catalog pg_stat_user_indexes
# Train on Information Schema: GMAO.pg_catalog pg_event_trigger
# Train on Information Schema: GMAO.pg_catalog pg_stats_ext_exprs
# Train on Information Schema: GMAO.pg_catalog pg_user
# Train on Information Schema: GMAO.pg_catalog pg_auth_members
# Train on Information Schema: GMAO.pg_catalog pg_replication_slots
# Train on Information Schema: GMAO.pg_catalog pg_attrdef
# Train on Information Schema: GMAO.pg_catalog pg_settings
# Train on Information Schema: GMAO.pg_catalog pg_stat_database_conflicts
# Train on Information Schema: GMAO.pg_catalog pg_ident_file_mappings
# Train on Information Schema: GMAO.pg_catalog pg_seclabel
# Train on Information Schema: GMAO.pg_catalog pg_aggregate
# Train on Information Schema: GMAO.pg_catalog pg_ts_template
# Train on Information Schema: GMAO.pg_catalog pg_proc
# Train on Information Schema: GMAO.pg_catalog pg_authid
# Train on Information Schema: GMAO.pg_catalog pg_stat_gssapi
# Train on Information Schema: GMAO.pg_catalog pg_stat_progress_create_index
# Train on Information Schema: GMAO.pg_catalog pg_user_mappings
# Train on Information Schema: GMAO.pg_catalog pg_prepared_statements
# Train on Information Schema: GMAO.pg_catalog pg_statio_all_tables
# Train on Information Schema: GMAO.pg_catalog pg_tablespace
# Train on Information Schema: GMAO.pg_catalog pg_constraint
# Train on Information Schema: GMAO.pg_catalog pg_stat_progress_copy
# Train on Information Schema: GMAO.pg_catalog pg_stat_xact_user_tables
# Train on Information Schema: GMAO.pg_catalog pg_shdepend
# Train on Information Schema: GMAO.pg_catalog pg_statistic
# Train on Information Schema: GMAO.pg_catalog pg_description
# Train on Information Schema: GMAO.pg_catalog pg_operator
# Train on Information Schema: GMAO.pg_catalog pg_publication_rel
# Train on Information Schema: GMAO.pg_catalog pg_stat_xact_all_tables
# Train on Information Schema: GMAO.pg_catalog pg_cursors
# Train on Information Schema: GMAO.pg_catalog pg_language
# Train on Information Schema: GMAO.pg_catalog pg_transform
# Train on Information Schema: GMAO.pg_catalog pg_ts_parser
# Train on Information Schema: GMAO.pg_catalog pg_timezone_names
# Train on Information Schema: GMAO.pg_catalog pg_statio_all_indexes
# Train on Information Schema: GMAO.pg_catalog pg_stats
# Train on Information Schema: GMAO.pg_catalog pg_db_role_setting
# Train on Information Schema: GMAO.pg_catalog pg_statistic_ext
# Train on Information Schema: GMAO.pg_catalog pg_stat_recovery_prefetch
# Train on Information Schema: GMAO.pg_catalog pg_extension
# Train on Information Schema: GMAO.pg_catalog pg_foreign_data_wrapper
# Train on Information Schema: GMAO.pg_catalog pg_stat_progress_analyze
# Train on Information Schema: GMAO.pg_catalog pg_seclabels
# Train on Information Schema: GMAO.pg_catalog pg_amop
# Train on Information Schema: GMAO.pg_catalog pg_backend_memory_contexts
# Train on Information Schema: GMAO.pg_catalog pg_subscription
# Train on Information Schema: GMAO.pg_catalog pg_publication
# Train on Information Schema: GMAO.pg_catalog pg_opclass
# Train on Information Schema: GMAO.pg_catalog pg_policies
# Train on Information Schema: GMAO.pg_catalog pg_matviews
# Train on Information Schema: GMAO.pg_catalog pg_stat_subscription
# Train on Information Schema: GMAO.pg_catalog pg_replication_origin
# Train on Information Schema: GMAO.pg_catalog pg_stat_user_functions
# Train on Information Schema: GMAO.pg_catalog pg_conversion
# Train on Information Schema: GMAO.pg_catalog pg_partitioned_table
# Train on Information Schema: GMAO.pg_catalog pg_range
# Train on Information Schema: GMAO.pg_catalog pg_roles
# Train on Information Schema: GMAO.pg_catalog pg_stat_slru
# Train on Information Schema: GMAO.pg_catalog pg_stat_archiver
# Train on Information Schema: GMAO.pg_catalog pg_user_mapping
# Train on Information Schema: GMAO.pg_catalog pg_stat_replication_slots
# Train on Information Schema: GMAO.pg_catalog pg_statio_sys_indexes
# Train on Information Schema: GMAO.pg_catalog pg_publication_namespace
# Train on Information Schema: GMAO.pg_catalog pg_ts_dict
# Train on Information Schema: GMAO.pg_catalog pg_parameter_acl
# Train on Information Schema: GMAO.pg_catalog pg_statistic_ext_data
# Train on Information Schema: GMAO.pg_catalog pg_statio_user_sequences
# Train on Information Schema: GMAO.pg_catalog pg_group
# Train on Information Schema: GMAO.pg_catalog pg_statio_sys_sequences
# Train on Information Schema: GMAO.pg_catalog pg_statio_all_sequences
# Train on Information Schema: GMAO.pg_catalog pg_inherits
# Train on Information Schema: GMAO.pg_catalog pg_ts_config_map
# Train on Information Schema: GMAO.pg_catalog pg_replication_origin_status
# Train on Information Schema: GMAO.pg_catalog pg_init_privs
# Train on Information Schema: GMAO.pg_catalog pg_foreign_table
# Train on Information Schema: GMAO.pg_catalog pg_rules
# Train on Information Schema: GMAO.pg_catalog pg_namespace
# Train on Information Schema: GMAO.pg_catalog pg_stat_subscription_stats
# Train on Information Schema: GMAO.pg_catalog pg_views
# Train on Information Schema: GMAO.pg_catalog pg_prepared_xacts
# Train on Information Schema: GMAO.pg_catalog pg_opfamily
# Train on Information Schema: GMAO.pg_catalog pg_am
# Train on Information Schema: GMAO.pg_catalog pg_shmem_allocations
# Train on Information Schema: GMAO.pg_catalog pg_timezone_abbrevs
# Train on Information Schema: GMAO.pg_catalog pg_shdescription
# Train on Information Schema: GMAO.pg_catalog pg_subscription_rel
# Train on Information Schema: GMAO.pg_catalog pg_config
# Train on Information Schema: GMAO.information_schema tables
# Train on Information Schema: GMAO.information_schema role_column_grants
# Train on Information Schema: GMAO.information_schema role_udt_grants
# Train on Information Schema: GMAO.information_schema column_domain_usage
# Train on Information Schema: GMAO.information_schema column_options
# Train on Information Schema: GMAO.information_schema attributes
# Train on Information Schema: GMAO.information_schema routine_table_usage
# Train on Information Schema: GMAO.information_schema sql_features
# Train on Information Schema: GMAO.information_schema routines
# Train on Information Schema: GMAO.information_schema foreign_table_options
# Train on Information Schema: GMAO.information_schema role_usage_grants
# Train on Information Schema: GMAO.information_schema role_routine_grants
# Train on Information Schema: GMAO.information_schema _pg_foreign_servers
# Train on Information Schema: GMAO.information_schema element_types
# Train on Information Schema: GMAO.information_schema parameters
# Train on Information Schema: GMAO.information_schema column_udt_usage
# Train on Information Schema: GMAO.information_schema routine_privileges
# Train on Information Schema: GMAO.information_schema column_column_usage
# Train on Information Schema: GMAO.information_schema sql_sizing
# Train on Information Schema: GMAO.information_schema routine_column_usage
# Train on Information Schema: GMAO.information_schema view_routine_usage
# Train on Information Schema: GMAO.information_schema columns
# Train on Information Schema: GMAO.information_schema _pg_user_mappings
# Train on Information Schema: GMAO.information_schema foreign_server_options
# Train on Information Schema: GMAO.information_schema triggers
# Train on Information Schema: GMAO.information_schema table_privileges
# Train on Information Schema: GMAO.information_schema domains
# Train on Information Schema: GMAO.information_schema constraint_column_usage
# Train on Information Schema: GMAO.information_schema character_sets
# Train on Information Schema: GMAO.information_schema role_table_grants
# Train on Information Schema: GMAO.information_schema foreign_servers
# Train on Information Schema: GMAO.information_schema _pg_foreign_data_wrappers
# Train on Information Schema: GMAO.information_schema constraint_table_usage
# Train on Information Schema: GMAO.information_schema data_type_privileges
# Train on Information Schema: GMAO.information_schema user_defined_types
# Train on Information Schema: GMAO.information_schema usage_privileges
# Train on Information Schema: GMAO.information_schema sequences
# Train on Information Schema: GMAO.information_schema administrable_role_authorizations
# Train on Information Schema: GMAO.information_schema information_schema_catalog_name
# Train on Information Schema: GMAO.information_schema table_constraints
# Train on Information Schema: GMAO.information_schema view_column_usage
# Train on Information Schema: GMAO.information_schema referential_constraints
# Train on Information Schema: GMAO.information_schema foreign_tables
# Train on Information Schema: GMAO.information_schema user_mapping_options
# Train on Information Schema: GMAO.information_schema column_privileges
# Train on Information Schema: GMAO.information_schema views
# Train on Information Schema: GMAO.information_schema triggered_update_columns
# Train on Information Schema: GMAO.information_schema schemata
# Train on Information Schema: GMAO.information_schema _pg_foreign_tables
# Train on Information Schema: GMAO.information_schema domain_constraints
# Train on Information Schema: GMAO.information_schema transforms
# Train on Information Schema: GMAO.information_schema udt_privileges
# Train on Information Schema: GMAO.information_schema collations
# Train on Information Schema: GMAO.information_schema key_column_usage
# Train on Information Schema: GMAO.information_schema routine_sequence_usage
# Train on Information Schema: GMAO.information_schema check_constraint_routine_usage
# Train on Information Schema: GMAO.information_schema sql_implementation_info
# Train on Information Schema: GMAO.information_schema foreign_data_wrapper_options
# Train on Information Schema: GMAO.information_schema routine_routine_usage
# Train on Information Schema: GMAO.information_schema sql_parts
# Train on Information Schema: GMAO.information_schema domain_udt_usage
# Train on Information Schema: GMAO.information_schema applicable_roles
# Train on Information Schema: GMAO.information_schema collation_character_set_applicability
# Train on Information Schema: GMAO.information_schema view_table_usage
# Train on Information Schema: GMAO.information_schema foreign_data_wrappers
# Train on Information Schema: GMAO.information_schema user_mappings
# Train on Information Schema: GMAO.information_schema enabled_roles
# Train on Information Schema: GMAO.information_schema check_constraints
# Train on Information Schema: GMAO.information_schema _pg_foreign_table_columns
# Train on Information Schema: GMAO.public demandes
# Train on Information Schema: GMAO.public fournisseurs
# Train on Information Schema: GMAO.public sites
# Train on Information Schema: GMAO.public emplacements
# Train on Information Schema: GMAO.public tables_atelier
# Train on Information Schema: GMAO.public historique
# Train on Information Schema: GMAO.public lieux
# Train on Information Schema: GMAO.public produits_listes_inventaire
# Train on Information Schema: GMAO.public inventaire
# Train on Information Schema: GMAO.public listes_inventaire

# %%
# Question simple - Liste des fournisseurs
vn.train(
    question="Liste-moi tous les fournisseurs",
    sql="SELECT nom_fournisseur, statut FROM fournisseurs ORDER BY nom_fournisseur;"
)

vn.train(
    question="Quels sont les fournisseurs actifs ?",
    sql="SELECT id_fournisseur, nom_fournisseur, contact1_email FROM fournisseurs WHERE statut = 'Actif';"
)

vn.train(
    question="Montre-moi les coordonnées du fournisseur X",
    sql="SELECT nom_fournisseur, adresse, contact1_nom, contact1_email, contact1_tel_mobile FROM fournisseurs WHERE nom_fournisseur ILIKE '%X%';"
)

vn.train(
    question="Combien de fournisseurs avons-nous ?",
    sql="SELECT COUNT(*) as nombre_fournisseurs FROM fournisseurs WHERE statut = 'Actif';"
)

# =====================================================
# QUESTIONS SUR L'INVENTAIRE/STOCK
# =====================================================

vn.train(
    question="Montre-moi tous les produits en stock",
    sql="SELECT reference, produits, quantite, emplacement, fournisseur FROM inventaire WHERE quantite > 0 ORDER BY produits;"
)

vn.train(
    question="Quels produits ont un stock faible ?",
    sql="SELECT reference, produits, quantite, stock_min, emplacement FROM inventaire WHERE quantite <= stock_min ORDER BY quantite;"
)

vn.train(
    question="Liste des produits par fournisseur",
    sql="SELECT fournisseur, COUNT(*) as nb_produits, SUM(quantite) as stock_total FROM inventaire GROUP BY fournisseur ORDER BY nb_produits DESC;"
)

vn.train(
    question="Quel est le stock total par catégorie ?",
    sql="SELECT categorie, COUNT(*) as nb_produits, SUM(quantite) as quantite_totale FROM inventaire GROUP BY categorie ORDER BY quantite_totale DESC;"
)

vn.train(
    question="Recherche un produit par référence",
    sql="SELECT * FROM inventaire WHERE reference = 'REF123';"
)

vn.train(
    question="Produits stockés dans l'emplacement X",
    sql="SELECT reference, produits, quantite, prix_unitaire FROM inventaire WHERE emplacement ILIKE '%X%';"
)

vn.train(
    question="Valeur totale du stock",
    sql="SELECT SUM(quantite * prix_unitaire) as valeur_totale_stock FROM inventaire;"
)

# =====================================================
# QUESTIONS SUR LA HIÉRARCHIE (SITES/LIEUX/EMPLACEMENTS)
# =====================================================

vn.train(
    question="Liste tous les sites",
    sql="SELECT code_site, nom_site, ville, responsable FROM sites WHERE statut = 'Actif';"
)

vn.train(
    question="Quels sont les lieux du site X ?",
    sql="SELECT l.code_lieu, l.nom_lieu, l.type_lieu, s.nom_site FROM lieux l JOIN sites s ON l.site_id = s.id WHERE s.nom_site ILIKE '%X%';"
)

vn.train(
    question="Montre-moi les emplacements du lieu Y",
    sql="SELECT e.code_emplacement, e.nom_emplacement, e.type_emplacement, e.nb_produits FROM emplacements e JOIN lieux l ON e.lieu_id = l.id WHERE l.nom_lieu ILIKE '%Y%';"
)

vn.train(
    question="Hiérarchie complète des emplacements",
    sql="SELECT s.nom_site, l.nom_lieu, e.nom_emplacement, e.nb_produits FROM sites s JOIN lieux l ON s.id = l.site_id JOIN emplacements e ON l.id = e.lieu_id ORDER BY s.nom_site, l.nom_lieu, e.nom_emplacement;"
)

# =====================================================
# QUESTIONS SUR LES DEMANDES
# =====================================================

vn.train(
    question="Liste des demandes en attente",
    sql="SELECT id_demande, date_demande, demandeur, statut FROM demandes WHERE statut = 'En attente' ORDER BY date_demande;"
)

vn.train(
    question="Demandes par demandeur",
    sql="SELECT demandeur, COUNT(*) as nb_demandes, MAX(date_demande) as derniere_demande FROM demandes GROUP BY demandeur ORDER BY nb_demandes DESC;"
)

vn.train(
    question="Demandes traitées ce mois",
    sql="SELECT COUNT(*) as demandes_traitees FROM demandes WHERE statut = 'Traitée' AND DATE_TRUNC('month', date_traitement) = DATE_TRUNC('month', CURRENT_DATE);"
)

# =====================================================
# QUESTIONS SUR L'HISTORIQUE
# =====================================================

vn.train(
    question="Historique des mouvements du produit X",
    sql="SELECT date_mouvement, nature, quantite_mouvement, quantite_avant, quantite_apres FROM historique WHERE produit ILIKE '%X%' ORDER BY date_mouvement DESC;"
)

vn.train(
    question="Mouvements d'entrée cette semaine",
    sql="SELECT reference, produit, quantite_mouvement, date_mouvement FROM historique WHERE nature = 'Entrée' AND date_mouvement >= DATE_TRUNC('week', CURRENT_DATE);"
)

vn.train(
    question="Mouvements de sortie par jour",
    sql="SELECT DATE(date_mouvement) as jour, COUNT(*) as nb_sorties, SUM(quantite_mouvement) as quantite_totale FROM historique WHERE nature = 'Sortie' GROUP BY DATE(date_mouvement) ORDER BY jour DESC;"
)

# =====================================================
# QUESTIONS SUR LES TABLES D'ATELIER
# =====================================================

vn.train(
    question="Liste des tables d'atelier",
    sql="SELECT id_table, nom_table, type_atelier, responsable FROM tables_atelier WHERE statut = 'Actif';"
)

vn.train(
    question="Tables d'atelier par responsable",
    sql="SELECT responsable, COUNT(*) as nb_tables FROM tables_atelier WHERE statut = 'Actif' GROUP BY responsable;"
)

# =====================================================
# QUESTIONS SUR LES LISTES D'INVENTAIRE
# =====================================================

vn.train(
    question="Listes d'inventaire en cours",
    sql="SELECT id_liste, nom_liste, statut, nb_produits, date_creation FROM listes_inventaire WHERE statut IN ('En préparation', 'En cours');"
)

vn.train(
    question="Produits dans la liste d'inventaire X",
    sql="SELECT reference_produit, nom_produit, quantite_theorique, quantite_comptee, emplacement FROM produits_listes_inventaire WHERE id_liste = 'X';"
)

# =====================================================
# QUESTIONS COMPLEXES AVEC JOINTURES
# =====================================================

vn.train(
    question="Produits et leurs fournisseurs avec contacts",
    sql="SELECT i.reference, i.produits, i.quantite, f.nom_fournisseur, f.contact1_email FROM inventaire i LEFT JOIN fournisseurs f ON i.fournisseur = f.nom_fournisseur WHERE i.quantite > 0;"
)

vn.train(
    question="Stock par site avec détails",
    sql="SELECT s.nom_site, l.nom_lieu, e.nom_emplacement, COUNT(i.id) as nb_produits, SUM(i.quantite) as stock_total FROM sites s JOIN lieux l ON s.id = l.site_id JOIN emplacements e ON l.id = e.lieu_id LEFT JOIN inventaire i ON CONCAT(s.nom_site, ' - ', l.nom_lieu, ' - ', e.nom_emplacement) = i.emplacement GROUP BY s.nom_site, l.nom_lieu, e.nom_emplacement ORDER BY stock_total DESC;"
)

vn.train(
    question="Analyse des ruptures de stock",
    sql="SELECT i.reference, i.produits, i.quantite, i.stock_min, f.nom_fournisseur, f.contact1_email FROM inventaire i LEFT JOIN fournisseurs f ON i.fournisseur = f.nom_fournisseur WHERE i.quantite <= i.stock_min ORDER BY (i.stock_min - i.quantite) DESC;"
)

# =====================================================
# QUESTIONS STATISTIQUES ET ANALYTIQUES
# =====================================================

vn.train(
    question="Top 10 des produits les plus stockés",
    sql="SELECT reference, produits, quantite, prix_unitaire, (quantite * prix_unitaire) as valeur FROM inventaire WHERE quantite > 0 ORDER BY quantite DESC LIMIT 10;"
)

vn.train(
    question="Répartition du stock par secteur",
    sql="SELECT secteur, COUNT(*) as nb_produits, SUM(quantite) as stock_total, AVG(prix_unitaire) as prix_moyen FROM inventaire WHERE secteur IS NOT NULL GROUP BY secteur ORDER BY stock_total DESC;"
)

vn.train(
    question="Évolution des entrées/sorties par mois",
    sql="SELECT DATE_TRUNC('month', date_mouvement) as mois, nature, COUNT(*) as nb_mouvements, SUM(quantite_mouvement) as quantite_totale FROM historique GROUP BY DATE_TRUNC('month', date_mouvement), nature ORDER BY mois DESC, nature;"
)

vn.train(
    question="Taux d'occupation des emplacements",
    sql="SELECT nom_emplacement, nb_produits, capacite_max, taux_occupation, (nb_produits::float / capacite_max * 100) as pourcentage_reel FROM emplacements WHERE capacite_max > 0 ORDER BY taux_occupation DESC;"
)

# =====================================================
# QUESTIONS DE RECHERCHE ET FILTRES
# =====================================================

vn.train(
    question="Recherche produit contenant 'vis'",
    sql="SELECT reference, produits, quantite, emplacement FROM inventaire WHERE produits ILIKE '%vis%' ORDER BY produits;"
)

vn.train(
    question="Produits ajoutés cette semaine",
    sql="SELECT reference, produits, quantite, date_entree FROM inventaire WHERE date_entree >= DATE_TRUNC('week', CURRENT_DATE) ORDER BY date_entree DESC;"
)

vn.train(
    question="Fournisseurs sans produits en stock",
    sql="SELECT f.nom_fournisseur, f.contact1_email FROM fournisseurs f LEFT JOIN inventaire i ON f.nom_fournisseur = i.fournisseur WHERE i.fournisseur IS NULL AND f.statut = 'Actif';"
)
# Out:
# 'cad29f19-371f-56ce-bfdd-7268e9f344b0-sql'

# %%
# =====================================================
# ENTRAÎNEMENT AVEC PAIRES QUESTION-SQL PERSONNALISÉES
# =====================================================

# Questions sur les fournisseurs
vn.train(
    question="Liste-moi tous les fournisseurs",
    sql="SELECT nom_fournisseur, statut FROM fournisseurs ORDER BY nom_fournisseur;"
)

vn.train(
    question="Quels sont les fournisseurs actifs ?",
    sql="SELECT id_fournisseur, nom_fournisseur, contact1_email FROM fournisseurs WHERE statut = 'Actif';"
)

vn.train(
    question="Combien de fournisseurs avons-nous ?",
    sql="SELECT COUNT(*) as nombre_fournisseurs FROM fournisseurs WHERE statut = 'Actif';"
)

# Questions sur l'inventaire
vn.train(
    question="Montre-moi tous les produits en stock",
    sql="SELECT reference, produits, quantite, emplacement, fournisseur FROM inventaire WHERE quantite > 0 ORDER BY produits;"
)

vn.train(
    question="Quels produits ont un stock faible ?",
    sql="SELECT reference, produits, quantite, stock_min, emplacement FROM inventaire WHERE quantite <= stock_min ORDER BY quantite;"
)

vn.train(
    question="Valeur totale du stock",
    sql="SELECT SUM(quantite * prix_unitaire) as valeur_totale_stock FROM inventaire;"
)

# Questions sur la hiérarchie
vn.train(
    question="Liste tous les sites",
    sql="SELECT code_site, nom_site, ville, responsable FROM sites WHERE statut = 'Actif';"
)

vn.train(
    question="Hiérarchie complète des emplacements",
    sql="SELECT s.nom_site, l.nom_lieu, e.nom_emplacement, e.nb_produits FROM sites s JOIN lieux l ON s.id = l.site_id JOIN emplacements e ON l.id = e.lieu_id ORDER BY s.nom_site, l.nom_lieu, e.nom_emplacement;"
)

# Questions complexes
vn.train(
    question="Produits et leurs fournisseurs avec contacts",
    sql="SELECT i.reference, i.produits, i.quantite, f.nom_fournisseur, f.contact1_email FROM inventaire i LEFT JOIN fournisseurs f ON i.fournisseur = f.nom_fournisseur WHERE i.quantite > 0;"
)

print("✅ Entraînement personnalisé terminé !")
# Out:
# Insert of existing embedding ID: 6ad00744-f6f1-5fda-9243-b2de39cd6989-sql
# Add of existing embedding ID: 6ad00744-f6f1-5fda-9243-b2de39cd6989-sql
# Insert of existing embedding ID: 25e202bb-2fcc-55f2-8a59-f4b872d71187-sql
# Add of existing embedding ID: 25e202bb-2fcc-55f2-8a59-f4b872d71187-sql
# Insert of existing embedding ID: 352c3c4f-4364-57e0-a468-43d3b72c246b-sql
# Add of existing embedding ID: 352c3c4f-4364-57e0-a468-43d3b72c246b-sql
# Insert of existing embedding ID: 8b9021c1-0aa4-5cf1-8b0a-e0bcedc10a21-sql
# Add of existing embedding ID: 8b9021c1-0aa4-5cf1-8b0a-e0bcedc10a21-sql
# Insert of existing embedding ID: 6a580a8e-dc98-5e55-bcdf-e43c130baa0e-sql
# Add of existing embedding ID: 6a580a8e-dc98-5e55-bcdf-e43c130baa0e-sql
# Insert of existing embedding ID: a2d56652-10b8-57b4-afdd-86aae9060c55-sql
# Add of existing embedding ID: a2d56652-10b8-57b4-afdd-86aae9060c55-sql
# Insert of existing embedding ID: 7f41cbc3-77d9-5b7c-b4c0-e21509702257-sql
# Add of existing embedding ID: 7f41cbc3-77d9-5b7c-b4c0-e21509702257-sql
# Insert of existing embedding ID: a3a8a2c5-a0ae-5652-af1a-6459b89bc74d-sql
# Add of existing embedding ID: a3a8a2c5-a0ae-5652-af1a-6459b89bc74d-sql
# Insert of existing embedding ID: f8b8dc1a-6cb1-5032-88c1-d84c16d370af-sql
# Add of existing embedding ID: f8b8dc1a-6cb1-5032-88c1-d84c16d370af-sql
# ✅ Entraînement personnalisé terminé !

# %%
from vanna.flask import VannaFlaskApp
VannaFlaskApp(vn, allow_llm_to_see_data=True).run()
# Out:
# Your app is running at:
# http://localhost:8084
#  * Serving Flask app 'vanna.flask'
#  * Debug mode: on
